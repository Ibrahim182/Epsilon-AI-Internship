# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(rc={'figure.figsize': [8, 4]}, font_scale=1.3)
from datasist.structdata import detect_outliers
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import KFold, GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Read data

# %%
df = pd.read_excel('Data/Data_Train.xlsx')
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %% [markdown]
# # Business case
# ### Weekend in India is on Sunday only.
# ### In India , National holidays vary according to its local state  but there’re ones which applied over the whole country like:
#   - 26 January -> Republic Day
#   - 15 August -> Independence Day
#   - 2 October -> Gandhi Jayanti

# %% [markdown]
# ### change date to day and month and year to be able to add new column has holidays

# %%
def date_process(df):
    # change type of date
    df['Date_of_Journey'] = pd.to_datetime(df['Date_of_Journey'], format='%d/%m/%Y')
    # extract year, month, day and day_name from date
    df['year'] = df['Date_of_Journey'].dt.year
    df['month'] = df['Date_of_Journey'].dt.month
    df['day_name'] = df['Date_of_Journey'].dt.day_name()
    df['day'] = df['Date_of_Journey'].dt.day
    # drop date_of_jpurney
    df.drop('Date_of_Journey', axis=1, inplace=True)
    return df

# %%
df = date_process(df)

# %%
# add holiday column
conditions = [(df['day_name'] == 'Sunday'), (df['month'] == 1) & (df['day'] == 26), (df['month'] == 8) & (df['day'] == 15), (df['month'] == 10) & (df['day'] == 2)]
value = [1, 1, 1, 1]
df['holiday'] = np.select(conditions, value)

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#    Arrival_Time Duration Total_Stops Additional_Info  Price  year  month  \
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897  2019      3
# 1         13:15   7h 25m     2 stops         No info   7662  2019      5
# 2  04:25 10 Jun      19h     2 stops         No info  13882  2019      6
# 3         23:30   5h 25m      1 stop         No info   6218  2019      5
# 4         21:35   4h 45m      1 stop         No info  13302  2019      3
#
#     day_name  day  holiday
# 0     Sunday   24        1
# 1  Wednesday    1        0
# 2     Sunday    9        1
# 3     Sunday   12        1
# 4     Friday    1        0

# %% [markdown]
# # EDA

# %%
# see unique values in additional info
df['Additional_Info'].unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover', 'No Info',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %% [markdown]
# - Notice 'No info' and 'No Info' so let's convert all object columns into lower case

# %% [markdown]
# ### Convert string columns into lower case

# %%
def to_lower(df):
  string_cols = ['Airline', 'Source', 'Destination', 'Dep_Time', 'Arrival_Time', 'Duration', 'Additional_Info']
  for i in string_cols:
    df[i] = df[i].apply(lambda s: s.lower())
  return df

# %%
df = to_lower(df)

# %%
# check value counts in Airline
df['Airline'].value_counts()
# Out:
# jet airways                          3849
# indigo                               2053
# air india                            1752
# multiple carriers                    1196
# spicejet                              818
# vistara                               479
# air asia                              319
# goair                                 194
# multiple carriers premium economy      13
# jet airways business                    6
# vistara premium economy                 3
# trujet                                  1
# Name: Airline, dtype: int64

# %% [markdown]
# ## Define some functions for ploting

# %%
# sub plots
def subplots(x,y):
    fig, axis = plt.subplots(x, y, figsize=(20,10))
    fig.tight_layout() # to fit
    plt.xticks(rotation=45);
    return axis

# %%
# to show precent of count in each category
def get_count_precent(ax):
  for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()-0., height, '{:1.2f}%'.format((height/len(df))*100), ha="center", fontsize=15)

# %%
# count plot
def count_plot(features, df):
  axis = subplots(2, 3)
  index = 0
  for i in range(2):
      for j in range(3):
        if index == len(features):
          break
        ax = sns.countplot(ax=axis[i][j],x=features[index],data=df)
        get_count_precent(ax)
        index += 1

# %%
categorical_features = ['Source', 'Destination','Total_Stops','month','day', 'day_name']
count_plot(categorical_features, df)

# %%
df['Additional_Info'].value_counts()
# Out:
# no info                         8348
# in-flight meal not included     1982
# no check-in baggage included     320
# 1 long layover                    19
# change airports                    7
# business class                     4
# 1 short layover                    1
# red-eye flight                     1
# 2 long layover                     1
# Name: Additional_Info, dtype: int64

# %% [markdown]
# # Preprocessing

# %%
new_df = df.copy()

# %%
new_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       indigo  banglore   new delhi              BLR → DEL    22:20
# 1    air india   kolkata    banglore  CCU → IXR → BBI → BLR    05:50
# 2  jet airways     delhi      cochin  DEL → LKO → BOM → COK    09:25
# 3       indigo   kolkata    banglore        CCU → NAG → BLR    18:05
# 4       indigo  banglore   new delhi        BLR → NAG → DEL    16:50
#
#    Arrival_Time Duration Total_Stops Additional_Info  Price  year  month  \
# 0  01:10 22 mar   2h 50m    non-stop         no info   3897  2019      3
# 1         13:15   7h 25m     2 stops         no info   7662  2019      5
# 2  04:25 10 jun      19h     2 stops         no info  13882  2019      6
# 3         23:30   5h 25m      1 stop         no info   6218  2019      5
# 4         21:35   4h 45m      1 stop         no info  13302  2019      3
#
#     day_name  day  holiday
# 0     Sunday   24        1
# 1  Wednesday    1        0
# 2     Sunday    9        1
# 3     Sunday   12        1
# 4     Friday    1        0

# %% [markdown]
# ## Check Null values

# %%
new_df.isnull().sum()
# Out:
# Airline            0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# year               0
# month              0
# day_name           0
# day                0
# holiday            0
# dtype: int64

# %%
# drop null values
new_df.dropna(axis=0, subset=['Total_Stops', 'Route'], inplace=True)
# reset indexes
new_df.reset_index(inplace=True)
new_df.drop(['index'], axis=1, inplace=True)

# %% [markdown]
# ## split Arrival time into hour and minutes,  day and month to check if the arrival date not before dept date

# %%
def split_arrival_time(df):
    df['Arrival_day'] = df['Arrival_Time'].str.split(' ').str[1]
    df['Arrival_month'] = df['Arrival_Time'].str.split(' ').str[2]
    df['Arrival_Time'] = df['Arrival_Time'].str.split(' ').str[0]
    df['Arrival_hour'] = df['Arrival_Time'].str.split(':').str[0].astype('int')
    df['Arrival_Minute'] = df['Arrival_Time'].str.split(':').str[1].astype('int')
    df.drop('Arrival_Time',axis=1,inplace=True)
    return df

# %%
new_df = split_arrival_time(new_df)

# %% [markdown]
# ### not all rows have arrival day and month so let's take who have

# %%
data_with_arrival_day = new_df[~new_df['Arrival_day'].isnull()]

# %%
# see unique months
data_with_arrival_day.Arrival_month.unique()
# Out:
# array(['mar', 'jun', 'may', 'apr'], dtype=object)

# %%
# map to convert month name into number
month = {'mar':3, 'jun':6, 'may':5, 'apr':4}

data_with_arrival_day['Arrival_month'] = data_with_arrival_day['Arrival_month'].apply(lambda x: month[x]).astype('int')

# %%
len(data_with_arrival_day)
# Out:
# 4334

# %%
data_with_arrival_day.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time Duration  \
# 0       indigo  banglore   new delhi              BLR → DEL    22:20   2h 50m
# 2  jet airways     delhi      cochin  DEL → LKO → BOM → COK    09:25      19h
# 6  jet airways  banglore   new delhi        BLR → BOM → DEL    18:55  15h 30m
# 7  jet airways  banglore   new delhi        BLR → BOM → DEL    08:00   21h 5m
# 8  jet airways  banglore   new delhi        BLR → BOM → DEL    08:55  25h 30m
#
#   Total_Stops              Additional_Info  Price  year  month day_name  day  \
# 0    non-stop                      no info   3897  2019      3   Sunday   24
# 2     2 stops                      no info  13882  2019      6   Sunday    9
# 6      1 stop  in-flight meal not included  11087  2019      3  Tuesday   12
# 7      1 stop                      no info  22270  2019      3   Friday    1
# 8      1 stop  in-flight meal not included  11087  2019      3  Tuesday   12
#
#    holiday Arrival_day  Arrival_month  Arrival_hour  Arrival_Minute
# 0        1          22              3             1              10
# 2        1          10              6             4              25
# 6        0          13              3            10              25
# 7        0          02              3             5               5
# 8        0          13              3            10              25

# %%
# convert arrival day into integer
data_with_arrival_day['Arrival_day'] = data_with_arrival_day['Arrival_day'].astype('int')

# %%
# indices of rows that have arrival day or month before dept day or month 
indices = data_with_arrival_day.index[(data_with_arrival_day['month'] > data_with_arrival_day['Arrival_month']) | (data_with_arrival_day['day'] > data_with_arrival_day['Arrival_day'])]

# %%
# drop indices
new_df.drop(axis=0, index=indices, inplace=True)

# %%
new_df.reset_index(inplace=True)
# drop arrival_day and month and index col
new_df.drop(['index', 'Arrival_day', 'Arrival_month'], axis=1, inplace=True)

# %%
new_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time Duration  \
# 0    air india   kolkata    banglore  CCU → IXR → BBI → BLR    05:50   7h 25m
# 1  jet airways     delhi      cochin  DEL → LKO → BOM → COK    09:25      19h
# 2       indigo   kolkata    banglore        CCU → NAG → BLR    18:05   5h 25m
# 3       indigo  banglore   new delhi        BLR → NAG → DEL    16:50   4h 45m
# 4     spicejet   kolkata    banglore              CCU → BLR    09:00   2h 25m
#
#   Total_Stops Additional_Info  Price  year  month   day_name  day  holiday  \
# 0     2 stops         no info   7662  2019      5  Wednesday    1        0
# 1     2 stops         no info  13882  2019      6     Sunday    9        1
# 2      1 stop         no info   6218  2019      5     Sunday   12        1
# 3      1 stop         no info  13302  2019      3     Friday    1        0
# 4    non-stop         no info   3873  2019      6     Monday   24        0
#
#    Arrival_hour  Arrival_Minute
# 0            13              15
# 1             4              25
# 2            23              30
# 3            21              35
# 4            11              25

# %% [markdown]
# ## Convert total stop into numbers

# %%
new_df['Total_Stops'].unique()
# Out:
# array(['2 stops', '1 stop', 'non-stop', '3 stops', '4 stops'],
#       dtype=object)

# %%
def change_total_stop(df):
    df['Total_Stops'] = df['Total_Stops'].map({'non-stop':0, '1 stop':1, '2 stops':2, '3 stops':3, '4 stops':4})
    return df

# %%
new_df = change_total_stop(new_df)

# %% [markdown]
# ## Split Departure Time into two columns one for hours and one for mins

# %%
def split_dep_time(df):
    df['Departure_Hour'] = df['Dep_Time'].str.split(':').str[0].astype('int')
    df['Departure_Minute'] = df['Dep_Time'].str.split(':').str[1].astype('int')
    df.drop('Dep_Time',axis=1,inplace=True)
    return df

# %%
new_df = split_dep_time(new_df)

# %% [markdown]
# ## check if column duration contain irrational values

# %%
all_durations = new_df['Duration']
all_durations = all_durations.str.split(' ')
for i in all_durations:
    if len(i) < 2 :
        if len(i[0].split('h')) < 2:
            print(i)
# Out:
# ['5m']

# %%
new_df[new_df['Duration'] == '5m']
# Out:
#         Airline  Source Destination                  Route Duration  \
# 6419  air india  mumbai   hyderabad  BOM → GOI → PNQ → HYD       5m
#
#       Total_Stops Additional_Info  Price  year  month   day_name  day  \
# 6419            2         no info  17327  2019      3  Wednesday    6
#
#       holiday  Arrival_hour  Arrival_Minute  Departure_Hour  Departure_Minute
# 6419        0            16              55              16                50

# %%
new_df.drop(axis=0, index=6474, inplace=True)
new_df.reset_index(inplace=True)
new_df.drop(['index'], axis=1, inplace=True)

# %%
new_df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0    air india   kolkata    banglore  CCU → IXR → BBI → BLR   7h 25m
# 1  jet airways     delhi      cochin  DEL → LKO → BOM → COK      19h
# 2       indigo   kolkata    banglore        CCU → NAG → BLR   5h 25m
# 3       indigo  banglore   new delhi        BLR → NAG → DEL   4h 45m
# 4     spicejet   kolkata    banglore              CCU → BLR   2h 25m
#
#    Total_Stops Additional_Info  Price  year  month   day_name  day  holiday  \
# 0            2         no info   7662  2019      5  Wednesday    1        0
# 1            2         no info  13882  2019      6     Sunday    9        1
# 2            1         no info   6218  2019      5     Sunday   12        1
# 3            1         no info  13302  2019      3     Friday    1        0
# 4            0         no info   3873  2019      6     Monday   24        0
#
#    Arrival_hour  Arrival_Minute  Departure_Hour  Departure_Minute
# 0            13              15               5                50
# 1             4              25               9                25
# 2            23              30              18                 5
# 3            21              35              16                50
# 4            11              25               9                 0

# %% [markdown]
# ## drop useless features

# %% [markdown]
# - we have arrival time and duration so let's drop duration
# - Route and stops let's drop route

# %%
def drop_useless_col(df, cols):
    df.drop(columns=cols, axis=1, inplace=True)
    return df

# %%
new_df = drop_useless_col(new_df, ['year', 'Route', 'Duration'])

# %%
new_df.head()
# Out:
#        Airline    Source Destination  Total_Stops Additional_Info  Price  \
# 0    air india   kolkata    banglore            2         no info   7662
# 1  jet airways     delhi      cochin            2         no info  13882
# 2       indigo   kolkata    banglore            1         no info   6218
# 3       indigo  banglore   new delhi            1         no info  13302
# 4     spicejet   kolkata    banglore            0         no info   3873
#
#    month   day_name  day  holiday  Arrival_hour  Arrival_Minute  \
# 0      5  Wednesday    1        0            13              15
# 1      6     Sunday    9        1             4              25
# 2      5     Sunday   12        1            23              30
# 3      3     Friday    1        0            21              35
# 4      6     Monday   24        0            11              25
#
#    Departure_Hour  Departure_Minute
# 0               5                50
# 1               9                25
# 2              18                 5
# 3              16                50
# 4               9                 0

# %% [markdown]
# ## Label encoding for categories data

# %%
le = LabelEncoder()
object_col = new_df.columns[new_df.dtypes == 'object']
new_df[object_col] = new_df[object_col].apply(le.fit_transform)

# %%
new_df.head()
# Out:
#    Airline  Source  Destination  Total_Stops  Additional_Info  Price  month  \
# 0        1       3            0            2                7   7662      5
# 1        4       2            1            2                7  13882      6
# 2        3       3            0            1                7   6218      5
# 3        3       0            5            1                7  13302      3
# 4        8       3            0            0                7   3873      6
#
#    day_name  day  holiday  Arrival_hour  Arrival_Minute  Departure_Hour  \
# 0         6    1        0            13              15               5
# 1         3    9        1             4              25               9
# 2         3   12        1            23              30              18
# 3         0    1        0            21              35              16
# 4         1   24        0            11              25               9
#
#    Departure_Minute
# 0                50
# 1                25
# 2                 5
# 3                50
# 4                 0

# %%
x = new_df.drop(axis=1, columns=['Price'])
y = new_df['Price']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# ## Scale

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
new_df.to_csv('preprocessing_data.csv', index=False)

# %% [markdown]
# # Models

# %%
# empty dataframe to append results
cols = ['model_name', 'train_score', 'test_score', 'MSE', 'MAE', 'R2', 'Adjusted_R2']
results = pd.DataFrame(columns=cols)

# %%
# these variables for adjusted r2 score
test_len = len(x_test)
cols_len = len(x.columns)

# %% [markdown]
# ## Kfold

# %%
kf = KFold(shuffle=True,random_state=42,n_splits=5)

# %% [markdown]
# ## Decision Tree

# %%
decsion_model = DecisionTreeRegressor(criterion='squared_error')
decsion_params = {
    "max_depth": [n for n in range(5, 13)],
    "random_state": [None, 42],
    "ccp_alpha": list(np.geomspace(0.001, 0.05, 20))
}

search = GridSearchCV(estimator=decsion_model, param_grid=decsion_params, cv=kf)
search.fit(x_train, y_train)
print("best_estimator_ ",search.best_estimator_)
# Out:
# best_estimator_  DecisionTreeRegressor(ccp_alpha=0.05, max_depth=12, random_state=42)

# %%
decsiontree_model = search.best_estimator_
decsiontree_model.fit(x_train, y_train)
train_score = decsiontree_model.score(x_train, y_train)
print('training score = ', train_score)
test_score = decsiontree_model.score(x_test, y_test)
print('testing score = ', test_score)
# Out:
# training score =  0.9425271732637601
# testing score =  0.7858722884270026

# %%
y_pred = decsiontree_model.predict(x_test)
MAE = mean_absolute_error(y_test, y_pred)
print('MAE = ', MAE)
MSE = np.sqrt(mean_squared_error(y_test, y_pred))
print('MSE = ', MSE)
R2 = r2_score(y_test, y_pred)
print('R2 = ', R2)
adj_r2 = 1-(1-R2)*(test_len-1)/(test_len-cols_len-1)
print('adjusted R2 = ', adj_r2)
# Out:
# MAE =  854.0049510131485
# MSE =  2036.8706751327384
# R2 =  0.7858722884270026
# adjusted R2 =  0.7845498845075495

# %%
results = results.append({'model_name':'Decsion_tree', 'train_score':train_score, 'test_score':test_score, 'MSE':MSE, 'MAE':MAE, 'R2':R2, 'Adjusted_R2':adj_r2}, ignore_index=True)

# %% [markdown]
# ## Random Forest

# %%
random_model = RandomForestRegressor()
random_params = {
    "n_estimators": [100, 150, 200],
    "max_depth": [6, 7, 8, 9, 10],
    "random_state": [None, 42]
}
search = GridSearchCV(estimator=random_model, param_grid=random_params, cv=kf)
search.fit(x_train, y_train)
print("best_estimator_ ",search.best_estimator_)
# Out:
# best_estimator_  RandomForestRegressor(max_depth=10)

# %%
randomforest_model = search.best_estimator_
randomforest_model.fit(x_train, y_train)
train_score = randomforest_model.score(x_train, y_train)
print('training score = ', train_score)
test_score = randomforest_model.score(x_test, y_test)
print('testing score = ', test_score)
# Out:
# training score =  0.9246154027114033
# testing score =  0.8382938641303753

# %%
y_pred = randomforest_model.predict(x_test)
MAE = mean_absolute_error(y_test, y_pred)
print('MAE = ', MAE)
MSE = np.sqrt(mean_squared_error(y_test, y_pred))
print('MSE = ', MSE)
R2 = r2_score(y_test, y_pred)
print('R2 = ', R2)
adj_r2 = 1-(1-R2)*(test_len-1)/(test_len-cols_len-1)
print('adjusted R2 = ', adj_r2)
# Out:
# MAE =  909.6963113875795
# MSE =  1770.069290904774
# R2 =  0.8382938641303753
# adjusted R2 =  0.8372952039088527

# %%
results = results.append({'model_name':'Random_forest', 'train_score':train_score, 'test_score':test_score, 'MSE':MSE, 'MAE':MAE, 'R2':R2, 'Adjusted_R2':adj_r2}, ignore_index=True)

# %% [markdown]
# ## XGB

# %%
# split train data into train and validation
xgb_train, x_val, ybg_train, y_val = train_test_split(x_train, y_train, test_size=0.1, random_state=42)

# %%
xgb_model = XGBRegressor()
xgb_params = {
    "n_estimators": [100, 150, 200],
    "max_depth": [7, 8, 9, 10, 11],
    "random_state": [None, 42],
    "learning_rate": [0.03, 0.01],
    "reg_alpha": [0, 0.01, 0.025],
}
search = RandomizedSearchCV(estimator=xgb_model, param_distributions=xgb_params, cv=kf)
search.fit(xgb_train, ybg_train, early_stopping_rounds=5, eval_set=[(x_val, y_val)])
print("best_estimator_ ",search.best_estimator_)
# Out:
# [11:17:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:10189.3
# Will train until validation_0-rmse hasn't improved in 5 rounds.
# [1]	validation_0-rmse:10094.7
# [2]	validation_0-rmse:10001.1
# [3]	validation_0-rmse:9908.42
# [4]	validation_0-rmse:9816.71
# [5]	validation_0-rmse:9725.92
# [6]	validation_0-rmse:9636.07
# [7]	validation_0-rmse:9547.15
# [8]	validation_0-rmse:9459.16
# [9]	validation_0-rmse:9372.08
# [10]	validation_0-rmse:9285.91
# [11]	validation_0-rmse:9200.63
# [12]	validation_0-rmse:9115.39
# [13]	validation_0-rmse:9031.04
# [14]	validation_0-rmse:8948.39
# [15]	validation_0-rmse:8865.79
# [16]	validation_0-rmse:8785.03
# [17]	validation_0-rmse:8704.29
# [18]	validation_0-rmse:8625.2
# [19]	validation_0-rmse:8546.14
# [20]	validation_0-rmse:8468.53
# [21]	validation_0-rmse:8392.2
# [22]	validation_0-rmse:8315.66
# [23]	validation_0-rmse:8240.71
# [24]	validation_0-rmse:8166.53
# [25]	validation_0-rmse:8092.44
# [26]	validation_0-rmse:8019.78
# [27]	validation_0-rmse:7948.12
# [28]	validation_0-rmse:7876.28
# [29]	validation_0-rmse:7806.18
# [30]	validation_0-rmse:7735.67
# [31]	validation_0-rmse:7666.78
# [32]	validation_0-rmse:7597.8
# [33]	validation_0-rmse:7530.46
# [34]	validation_0-rmse:7462.87
# [35]	validation_0-rmse:7396.78
# [36]	validation_0-rmse:7331.4
# [37]	validation_0-rmse:7266.01
# [38]	validation_0-rmse:7202.12
# [39]	validation_0-rmse:7138.93
# [40]	validation_0-rmse:7075.77
# [41]	validation_0-rmse:7013.93
# [42]	validation_0-rmse:6951.97
# [43]	validation_0-rmse:6891.17
# [44]	validation_0-rmse:6831.42
# [45]	validation_0-rmse:6771.46
# [46]	validation_0-rmse:6712.69
# [47]	validation_0-rmse:6654.74
# [48]	validation_0-rmse:6596.66
# [49]	validation_0-rmse:6539.58
# [50]	validation_0-rmse:6482.91
# [51]	validation_0-rmse:6427.42
# [52]	validation_0-rmse:6372.05
# [53]	validation_0-rmse:6317.75
# [54]	validation_0-rmse:6263.74
# [55]	validation_0-rmse:6210.43
# [56]	validation_0-rmse:6157.36
# [57]	validation_0-rmse:6105
# [58]	validation_0-rmse:6053.61
# [59]	validation_0-rmse:6002.76
# [60]	validation_0-rmse:5951.98
# [61]	validation_0-rmse:5901.82
# [62]	validation_0-rmse:5853.06
# [63]	validation_0-rmse:5803.34
# [64]	validation_0-rmse:5755.53
# [65]	validation_0-rmse:5707.04
# [66]	validation_0-rmse:5659.89
# [67]	validation_0-rmse:5612.42
# [68]	validation_0-rmse:5566.45
# [69]	validation_0-rmse:5520.39
# [70]	validation_0-rmse:5475.59
# [71]	validation_0-rmse:5430.28
# [72]	validation_0-rmse:5386.38
# [73]	validation_0-rmse:5342.56
# [74]	validation_0-rmse:5299.53
# [75]	validation_0-rmse:5256.8
# [76]	validation_0-rmse:5214.77
# [77]	validation_0-rmse:5171.74
# [78]	validation_0-rmse:5129.11
# [79]	validation_0-rmse:5087.02
# [80]	validation_0-rmse:5045.9
# [81]	validation_0-rmse:5005.86
# [82]	validation_0-rmse:4965.52
# [83]	validation_0-rmse:4925.23
# [84]	validation_0-rmse:4885.41
# [85]	validation_0-rmse:4846.12
# [86]	validation_0-rmse:4808.28
# [87]	validation_0-rmse:4771.22
# [88]	validation_0-rmse:4733.26
# [89]	validation_0-rmse:4696.79
# [90]	validation_0-rmse:4661.25
# [91]	validation_0-rmse:4624.62
# [92]	validation_0-rmse:4589.26
# [93]	validation_0-rmse:4554.58
# [94]	validation_0-rmse:4519.17
# [95]	validation_0-rmse:4484.15
# [96]	validation_0-rmse:4449.99
# [97]	validation_0-rmse:4416.79
# [98]	validation_0-rmse:4383.01
# [99]	validation_0-rmse:4351.02
# [100]	validation_0-rmse:4318.02
# [101]	validation_0-rmse:4286.6
# [102]	validation_0-rmse:4255.62
# [103]	validation_0-rmse:4223.92
# [104]	validation_0-rmse:4192.44
# [105]	validation_0-rmse:4162.37
# [106]	validation_0-rmse:4132.65
# [107]	validation_0-rmse:4102.3
# [108]	validation_0-rmse:4073.19
# [109]	validation_0-rmse:4044.46
# [110]	validation_0-rmse:4015.76
# [111]	validation_0-rmse:3987.94
# [112]	validation_0-rmse:3959.49
# [113]	validation_0-rmse:3931.66
# [114]	validation_0-rmse:3904.37
# [115]	validation_0-rmse:3876.07
# [116]	validation_0-rmse:3849.23
# [117]	validation_0-rmse:3822.93
# [118]	validation_0-rmse:3797.34
# [119]	validation_0-rmse:3770.71
# [120]	validation_0-rmse:3745.1
# [121]	validation_0-rmse:3720
# [122]	validation_0-rmse:3693.79
# [123]	validation_0-rmse:3669.88
# [124]	validation_0-rmse:3645.75
# [125]	validation_0-rmse:3620.46
# [126]	validation_0-rmse:3597.6
# [127]	validation_0-rmse:3573.29
# [128]	validation_0-rmse:3549.65
# [129]	validation_0-rmse:3525.89
# [130]	validation_0-rmse:3502.76
# [131]	validation_0-rmse:3480.85
# [132]	validation_0-rmse:3458.12
# [133]	validation_0-rmse:3435.8
# [134]	validation_0-rmse:3414.78
# [135]	validation_0-rmse:3392.81
# [136]	validation_0-rmse:3372.03
# [137]	validation_0-rmse:3350.42
# [138]	validation_0-rmse:3329.66
# [139]	validation_0-rmse:3308.83
# [140]	validation_0-rmse:3289.2
# [141]	validation_0-rmse:3268.9
# [142]	validation_0-rmse:3249.29
# [143]	validation_0-rmse:3229.01
# [144]	validation_0-rmse:3210.8
# [145]	validation_0-rmse:3191.34
# [146]	validation_0-rmse:3172.38
# [147]	validation_0-rmse:3153.37
# [148]	validation_0-rmse:3136.14
# [149]	validation_0-rmse:3117.31
# [150]	validation_0-rmse:3100.39
# [151]	validation_0-rmse:3082.27
# [152]	validation_0-rmse:3064.42
# [153]	validation_0-rmse:3046.88
# [154]	validation_0-rmse:3029.59
# [155]	validation_0-rmse:3014.07
# [156]	validation_0-rmse:2996.85
# [157]	validation_0-rmse:2980.23
# [158]	validation_0-rmse:2963.73
# [159]	validation_0-rmse:2949.03
# [160]	validation_0-rmse:2933
# [161]	validation_0-rmse:2917.16
# [162]	validation_0-rmse:2901.53
# [163]	validation_0-rmse:2887.74
# [164]	validation_0-rmse:2872.64
# [165]	validation_0-rmse:2858.06
# [166]	validation_0-rmse:2843.63
# [167]	validation_0-rmse:2830.56
# [168]	validation_0-rmse:2816.6
# [169]	validation_0-rmse:2802.88
# [170]	validation_0-rmse:2790.41
# [171]	validation_0-rmse:2776.56
# [172]	validation_0-rmse:2762.84
# [173]	validation_0-rmse:2750.86
# [174]	validation_0-rmse:2737.55
# [175]	validation_0-rmse:2724.64
# [176]	validation_0-rmse:2713.09
# [177]	validation_0-rmse:2700.35
# [178]	validation_0-rmse:2689.27
# [179]	validation_0-rmse:2676.83
# [180]	validation_0-rmse:2665.05
# [181]	validation_0-rmse:2652.89
# [182]	validation_0-rmse:2642.51
# [183]	validation_0-rmse:2630.68
# [184]	validation_0-rmse:2619.5
# [185]	validation_0-rmse:2607.96
# [186]	validation_0-rmse:2596.75
# [187]	validation_0-rmse:2586.97
# [188]	validation_0-rmse:2575.74
# [189]	validation_0-rmse:2565.02
# [190]	validation_0-rmse:2554.24
# [191]	validation_0-rmse:2543.8
# [192]	validation_0-rmse:2534.65
# [193]	validation_0-rmse:2524.01
# [194]	validation_0-rmse:2513.95
# [195]	validation_0-rmse:2503.53
# [196]	validation_0-rmse:2494.91
# [197]	validation_0-rmse:2484.87
# [198]	validation_0-rmse:2475.54
# [199]	validation_0-rmse:2465.65
# [11:17:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:10189.8
# Will train until validation_0-rmse hasn't improved in 5 rounds.
# [1]	validation_0-rmse:10095.3
# [2]	validation_0-rmse:10002.1
# [3]	validation_0-rmse:9909.61
# [4]	validation_0-rmse:9818.31
# [5]	validation_0-rmse:9727.71
# [6]	validation_0-rmse:9638.29
# [7]	validation_0-rmse:9549.55
# [8]	validation_0-rmse:9461.97
# [9]	validation_0-rmse:9375.03
# [10]	validation_0-rmse:9289.26
# [11]	validation_0-rmse:9204.15
# [12]	validation_0-rmse:9120.18
# [13]	validation_0-rmse:9036.86
# [14]	validation_0-rmse:8954.65
# [15]	validation_0-rmse:8873.02
# [16]	validation_0-rmse:8792.53
# [17]	validation_0-rmse:8712.71
# [18]	validation_0-rmse:8633.96
# [19]	validation_0-rmse:8555.74
# [20]	validation_0-rmse:8478.44
# [21]	validation_0-rmse:8401.99
# [22]	validation_0-rmse:8326.72
# [23]	validation_0-rmse:8251.84
# [24]	validation_0-rmse:8177.86
# [25]	validation_0-rmse:8103.93
# [26]	validation_0-rmse:8031.51
# [27]	validation_0-rmse:7958.92
# [28]	validation_0-rmse:7888.01
# [29]	validation_0-rmse:7817.11
# [30]	validation_0-rmse:7747.73
# [31]	validation_0-rmse:7678.06
# [32]	validation_0-rmse:7610.21
# [33]	validation_0-rmse:7542.24
# [34]	validation_0-rmse:7475.8
# [35]	validation_0-rmse:7409.1
# [36]	validation_0-rmse:7343.73
# [37]	validation_0-rmse:7279.62
# [38]	validation_0-rmse:7214.85
# [39]	validation_0-rmse:7152.05
# [40]	validation_0-rmse:7088.99
# [41]	validation_0-rmse:7027.37
# [42]	validation_0-rmse:6965.47
# [43]	validation_0-rmse:6905.33
# [44]	validation_0-rmse:6844.72
# [45]	validation_0-rmse:6785.87
# [46]	validation_0-rmse:6726.65
# [47]	validation_0-rmse:6668.93
# [48]	validation_0-rmse:6610.87
# [49]	validation_0-rmse:6554.34
# [50]	validation_0-rmse:6497.5
# [51]	validation_0-rmse:6442.4
# [52]	validation_0-rmse:6386.66
# [53]	validation_0-rmse:6332.75
# [54]	validation_0-rmse:6278.38
# [55]	validation_0-rmse:6225.45
# [56]	validation_0-rmse:6171.95
# [57]	validation_0-rmse:6120.05
# [58]	validation_0-rmse:6067.84
# [59]	validation_0-rmse:6017.09
# [60]	validation_0-rmse:5966.09
# [61]	validation_0-rmse:5916.47
# [62]	validation_0-rmse:5866.36
# [63]	validation_0-rmse:5817.87
# [64]	validation_0-rmse:5769.21
# [65]	validation_0-rmse:5721.65
# [66]	validation_0-rmse:5673.77
# [67]	validation_0-rmse:5627.24
# [68]	validation_0-rmse:5580.76
# [69]	validation_0-rmse:5535.2
# [70]	validation_0-rmse:5489.26
# [71]	validation_0-rmse:5444.97
# [72]	validation_0-rmse:5400.35
# [73]	validation_0-rmse:5357.03
# [74]	validation_0-rmse:5313
# [75]	validation_0-rmse:5270.56
# [76]	validation_0-rmse:5227.92
# [77]	validation_0-rmse:5185.65
# [78]	validation_0-rmse:5144.57
# [79]	validation_0-rmse:5103.07
# [80]	validation_0-rmse:5063.06
# [81]	validation_0-rmse:5022.99
# [82]	validation_0-rmse:4983.68
# [83]	validation_0-rmse:4944.05
# [84]	validation_0-rmse:4905.79
# [85]	validation_0-rmse:4867.43
# [86]	validation_0-rmse:4830.15
# [87]	validation_0-rmse:4792.24
# [88]	validation_0-rmse:4755.67
# [89]	validation_0-rmse:4719.15
# [90]	validation_0-rmse:4682.66
# [91]	validation_0-rmse:4646.5
# [92]	validation_0-rmse:4611.62
# [93]	validation_0-rmse:4577.04
# [94]	validation_0-rmse:4542.83
# [95]	validation_0-rmse:4508.33
# [96]	validation_0-rmse:4474.24
# [97]	validation_0-rmse:4440.19
# [98]	validation_0-rmse:4406.86
# [99]	validation_0-rmse:4373.93
# [100]	validation_0-rmse:4341.34
# [101]	validation_0-rmse:4308.71
# [102]	validation_0-rmse:4277.25
# [103]	validation_0-rmse:4245.86
# [104]	validation_0-rmse:4213.97
# [105]	validation_0-rmse:4183.39
# [106]	validation_0-rmse:4152.33
# [107]	validation_0-rmse:4122.71
# [108]	validation_0-rmse:4093.02
# [109]	validation_0-rmse:4063.24
# [110]	validation_0-rmse:4033.55
# [111]	validation_0-rmse:4005.26
# [112]	validation_0-rmse:3977.22
# [113]	validation_0-rmse:3948.58
# [114]	validation_0-rmse:3921.11
# [115]	validation_0-rmse:3893.31
# [116]	validation_0-rmse:3866.58
14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:10189.7
# Will train until validation_0-rmse hasn't improved in 5 rounds.
# [1]	validation_0-rmse:10095.5
# [2]	validation_0-rmse:10002.2
# [3]	validation_0-rmse:9909.91
# [4]	validation_0-rmse:9818.39
# [5]	validation_0-rmse:9727.98
# [6]	validation_0-rmse:9638.33
# [7]	validation_0-rmse:9549.7
# [8]	validation_0-rmse:9461.83
# [9]	validation_0-rmse:9375.1
# [10]	validation_0-rmse:9289.05
# [11]	validation_0-rmse:9204.17
# [12]	validation_0-rmse:9119.98
# [13]	validation_0-rmse:9036.78
# [14]	validation_0-rmse:8954.34
# [15]	validation_0-rmse:8872.94
# [16]	validation_0-rmse:8792.3
# [17]	validation_0-rmse:8712.48
# [18]	validation_0-rmse:8633.41
# [19]	validation_0-rmse:8555.31
# [20]	validation_0-rmse:8477.85
# [21]	validation_0-rmse:8401.46
# [22]	validation_0-rmse:8325.7
# [23]	validation_0-rmse:8250.88
# [24]	validation_0-rmse:8175.27
# [25]	validation_0-rmse:8101.99
# [26]	validation_0-rmse:8029.5
# [27]	validation_0-rmse:7957.72
# [28]	validation_0-rmse:7885.3
# [29]	validation_0-rmse:7813.59
# [30]	validation_0-rmse:7742.73
# [31]	validation_0-rmse:7672.67
# [32]	validation_0-rmse:7603.28
# [33]	validation_0-rmse:7534.59
# [34]	validation_0-rmse:7466.6
# [35]	validation_0-rmse:7399.4
# [36]	validation_0-rmse:7332.85
# [37]	validation_0-rmse:7267.12
# [38]	validation_0-rmse:7201.97
# [39]	validation_0-rmse:7137.55
# [40]	validation_0-rmse:7073.74
# [41]	validation_0-rmse:7010.75
# [42]	validation_0-rmse:6948.28
# [43]	validation_0-rmse:6886.63
# [44]	validation_0-rmse:6825.53
# [45]	validation_0-rmse:6765.16
# [46]	validation_0-rmse:6705.42
# [47]	validation_0-rmse:6646.38
# [48]	validation_0-rmse:6587.9
# [49]	validation_0-rmse:6530.07
# [50]	validation_0-rmse:6473.22
# [51]	validation_0-rmse:6417.05
# [52]	validation_0-rmse:6361.14
# [53]	validation_0-rmse:6306.17
# [54]	validation_0-rmse:6251.86
# [55]	validation_0-rmse:6197.68
# [56]	validation_0-rmse:6144.44
# [57]	validation_0-rmse:6091.82
# [58]	validation_0-rmse:6039.41
# [59]	validation_0-rmse:5987.91
# [60]	validation_0-rmse:5936.99
# [61]	validation_0-rmse:5886.31
# [62]	validation_0-rmse:5836.56
# [63]	validation_0-rmse:5787.27
# [64]	validation_0-rmse:5738.31
# [65]	validation_0-rmse:5690.66
# [66]	validation_0-rmse:5642.75
# [67]	validation_0-rmse:5596.34
# [68]	validation_0-rmse:5549.69
# [69]	validation_0-rmse:5504.2
# [70]	validation_0-rmse:5458.3
# [71]	validation_0-rmse:5413.88
# [72]	validation_0-rmse:5369.74
# [73]	validation_0-rmse:5325.82
# [74]	validation_0-rmse:5282.03
# [75]	validation_0-rmse:5239.18
# [76]	validation_0-rmse:5196.29
# [77]	validation_0-rmse:5154.5
# [159]	validation_0-rmse:2928.92
# [160]	validation_0-rmse:2913.12
# [161]	validation_0-rmse:2898.59
# [162]	validation_0-rmse:2882.48
# [163]	validation_0-rmse:2866.59
# [164]	validation_0-rmse:2850.98
# [165]	validation_0-rmse:2836.98
# [166]	validation_0-rmse:2822.28
# [167]	validation_0-rmse:2807.09
# [168]	validation_0-rmse:2794.11
# [169]	validation_0-rmse:2780.01
# [170]	validation_0-rmse:2765.35
# [171]	validation_0-rmse:2752.68
# [172]	validation_0-rmse:2739.07
# [173]	validation_0-rmse:2725.58
# [174]	validation_0-rmse:2712.56
# [175]	validation_0-rmse:2699.44
# [176]	validation_0-rmse:2686.97
# [177]	validation_0-rmse:2675.18
# [178]	validation_0-rmse:2662.79
# [179]	validation_0-rmse:2650.76
# [180]	validation_0-rmse:2639.59
# [181]	validation_0-rmse:2627.54
# [182]	validation_0-rmse:2615.75
# [183]	validation_0-rmse:2604.06
# [184]	validation_0-rmse:2593.52
# [185]	validation_0-rmse:2582.21
# [186]	validation_0-rmse:2571.09
# [187]	validation_0-rmse:2560.02
# [188]	validation_0-rmse:2550.09
# [189]	validation_0-rmse:2539.13
# [190]	validation_0-rmse:2528.63
# [191]	validation_0-rmse:2517.88
# [192]	validation_0-rmse:2508.43
# [193]	validation_0-rmse:2498.19
# [194]	validation_0-rmse:2488.18
# [195]	validation_0-rmse:2478.85
# [196]	validation_0-rmse:2468.93
# [197]	validation_0-rmse:2459.12
# [198]	validation_0-rmse:2450.45
# [199]	validation_0-rmse:2440.67
# [11:17:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:10189.4
# Will train until validation_0-rmse hasn't improved in 5 rounds.
# [1]	validation_0-rmse:10094.8
# [2]	validation_0-rmse:10001.3
# [3]	validation_0-rmse:9908.65
# [4]	validation_0-rmse:9816.98
# [5]	validation_0-rmse:9726.25
# [6]	validation_0-rmse:9635.8
# [7]	validation_0-rmse:9546.2
# [8]	validation_0-rmse:9457.57
# [9]	validation_0-rmse:9370.25
# [10]	validation_0-rmse:9283.39
# [11]	validation_0-rmse:9197.99
# [12]	validation_0-rmse:9113.63
# [13]	validation_0-rmse:9029.37
# [14]	validation_0-rmse:8946.73
# [15]	validation_0-rmse:8864.39
# [16]	validation_0-rmse:8783.45
# [17]	validation_0-rmse:8703.04
# [18]	validation_0-rmse:8623.8
# [19]	validation_0-rmse:8544.95
# [20]	validation_0-rmse:8467.2
# [21]	validation_0-rmse:8390.23
# [22]	validation_0-rmse:8314.48
# [23]	validation_0-rmse:8238.71
# [24]	validation_0-rmse:8164.19
# [25]	validation_0-rmse:8090.4
# [26]	validation_0-rmse:8017.71
# [27]	validation_0-rmse:7945.01
# [28]	validation_0-rmse:7873.83
# [29]	validation_0-rmse:7802.78
# [30]	validation_0-rmse:7732.83
# [31]	validation_0-rmse:7663.78
# [32]	validation_0-rmse:7595.34
# [33]	validation_0-rmse:7527.97
# [34]	validation_0-rmse:7460.52
# [35]	validation_0-rmse:7394.17
# [36]	validation_0-rmse:7328.75
# [37]	validation_0-rmse:7263.94
# [38]	validation_0-rmse:7199.43
# [39]	validation_0-rmse:7136.18
# [40]	validation_0-rmse:7072.83
# [41]	validation_0-rmse:7010.49
# [42]	validation_0-rmse:6949.08
# [43]	validation_0-rmse:6888.52
# [44]	validation_0-rmse:6828.08
# [45]	validation_0-rmse:6768.37
# [46]	validation_0-rmse:6709.48
# [47]	validation_0-rmse:6651.52
# [48]	validation_0-rmse:6593.42
# [49]	validation_0-rmse:6536.53
# [50]	validation_0-rmse:6480.17
# [51]	validation_0-rmse:6424.69
# [52]	validation_0-rmse:6369.21
# [53]	validation_0-rmse:6314.84
# [54]	validation_0-rmse:6260.61
# [55]	validation_0-rmse:6207.15
# [56]	validation_0-rmse:6153.71
# [57]	validation_0-rmse:6101.52
# [58]	validation_0-rmse:6049.76
# [59]	validation_0-rmse:5998.42
# [60]	validation_0-rmse:5947.35
# [61]	validation_0-rmse:5897.31
# [62]	validation_0-rmse:5848.07
# [63]	validation_0-rmse:5798.95
# [64]	validation_0-rmse:5750.12
# [65]	validation_0-rmse:5702.27
# [66]	validation_0-rmse:5654.85
# [67]	validation_0-rmse:5608.6
# [68]	validation_0-rmse:5561.5
# [69]	validation_0-rmse:5515.43
# [70]	validation_0-rmse:5470.45
# [71]	validation_0-rmse:5425.94
# [72]	validation_0-rmse:5380.8
# [73]	validation_0-rmse:5337.27
# [74]	validation_0-rmse:5293.16
# [75]	validation_0-rmse:5250.77
# [76]	validation_0-rmse:5208.3
# [77]	validation_0-rmse:5166.74
# [78]	validation_0-rmse:5124.86
# [79]	validation_0-rmse:5084.38
# [80]	validation_0-rmse:5043.51
# [81]	validation_0-rmse:5004.5
# [82]	validation_0-rmse:4965.46
# [83]	validation_0-rmse:4927.3
# [84]	validation_0-rmse:4888.86
# [85]	validation_0-rmse:4851.33
# [86]	validation_0-rmse:4813.87
# [87]	validation_0-rmse:4775.42
# [88]	validation_0-rmse:4738.49
# [89]	validation_0-rmse:4703
# [90]	validation_0-rmse:4665.81
# [91]	validation_0-rmse:4628.73
# [92]	validation_0-rmse:4593.98
# [93]	validation_0-rmse:4560.04
# [94]	validation_0-rmse:4524.25
# [95]	validation_0-rmse:4489.03
# [96]	validation_0-rmse:4455.88
# [97]	validation_0-rmse:4422.44
# [98]	validation_0-rmse:4390.35
# [99]	validation_0-rmse:4356.55
# [100]	validation_0-rmse:4323.28
# [101]	validation_0-rmse:4291.7
# [102]	validation_0-rmse:4260.53
# [103]	validation_0-rmse:4229.74
# [104]	validation_0-rmse:4198.03
# [105]	validation_0-rmse:4168.46
# [106]	validation_0-rmse:4137.3
# [107]	validation_0-rmse:4106.54
# [108]	validation_0-rmse:4076.97
# [109]	validation_0-rmse:4047.03
# [110]	validation_0-rmse:4018.64
# [111]	validation_0-rmse:3990.71
# [112]	validation_0-rmse:3963.12
# [113]	validation_0-rmse:3936.01
# [114]	validation_0-rmse:3907.5
# [115]	validation_0-rmse:3879.18
# [116]	validation_0-rmse:3853.17
# [117]	validation_0-rmse:3825.6
# [118]	validation_0-rmse:3799.94
19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:10190.5
# Will train until validation_0-rmse hasn't improved in 5 rounds.
# [1]	validation_0-rmse:10097
# [2]	validation_0-rmse:10004.5
# [3]	validation_0-rmse:9913.01
# [4]	validation_0-rmse:9822.41
# [5]	validation_0-rmse:9732.82
# [6]	validation_0-rmse:9644.16
# [7]	validation_0-rmse:9556.7
# [8]	validation_0-rmse:9469.84
# [9]	validation_0-rmse:9384.2
# [10]	validation_0-rmse:9299.61
# [11]	validation_0-rmse:9215.56
# [12]	validation_0-rmse:9132.73
# [13]	validation_0-rmse:9050.71
# [14]	validation_0-rmse:8969.37
# [15]	validation_0-rmse:8889.06
# [16]	validation_0-rmse:8809.27
# [17]	validation_0-rmse:8730.71
# [18]	validation_0-rmse:8652.85
# [19]	validation_0-rmse:8575.57
# [20]	validation_0-rmse:8499.33
# [21]	validation_0-rmse:8424.22
# [22]	validation_0-rmse:8349.39
# [23]	validation_0-rmse:8275.86
# [24]	validation_0-rmse:8203.33
# [25]	validation_0-rmse:8130.9
# [26]	validation_0-rmse:8059.61
# [27]	validation_0-rmse:7988.64
# [28]	validation_0-rmse:7919
# [29]	validation_0-rmse:7850.13
# [30]	validation_0-rmse:7781.65
# [31]	validation_0-rmse:7714.38
# [32]	validation_0-rmse:7647.89
# [33]	validation_0-rmse:7581.57
# [34]	validation_0-rmse:7516.4
# [35]	validation_0-rmse:7451.89
# [36]	validation_0-rmse:7388.06
# [37]	validation_0-rmse:7325.07
# [38]	validation_0-rmse:7262.76
# [39]	validation_0-rmse:7201.04
# [40]	validation_0-rmse:7140.03
# [41]	validation_0-rmse:7079.71
# [42]	validation_0-rmse:7020.04
# [43]	validation_0-rmse:6961.17
# [44]	validation_0-rmse:6902.74
# [45]	validation_0-rmse:6844.98
# [46]	validation_0-rmse:6787.79
# [47]	validation_0-rmse:6731.48
# [48]	validation_0-rmse:6675.59
# [49]	validation_0-rmse:6620.28
# [50]	validation_0-rmse:6565.84
# [51]	validation_0-rmse:6511.85
# [52]	validation_0-rmse:6458.4
# [53]	validation_0-rmse:6405.18
# [54]	validation_0-rmse:6352.79
# [55]	validation_0-rmse:6300.69
# [56]	validation_0-rmse:6249.43
# [57]	validation_0-rmse:6198.69
# [58]	validation_0-rmse:6148.45
# [59]	validation_0-rmse:6099.12
# [60]	validation_0-rmse:6050.15
# [61]	validation_0-rmse:6001.66
# [62]	validation_0-rmse:5954.01
# [63]	validation_0-rmse:5906.88
# [64]	validation_0-rmse:5860.47
# [65]	validation_0-rmse:5814.12
# [66]	validation_0-rmse:5768.43
# [67]	validation_0-rmse:5723.37
# [68]	validation_0-rmse:5679.1
# [69]	validation_0-rmse:5635.08
# [70]	validation_0-rmse:5591.13
# [71]	validation_0-rmse:5548.59
# [72]	validation_0-rmse:5505.86
# [73]	validation_0-rmse:5464.34
# [74]	validation_0-rmse:5422.53
# [75]	validation_0-rmse:5381.85
# [76]	validation_0-rmse:5341.72
# [77]	validation_0-rmse:5301.58
# [78]	validation_0-rmse:5261.58
# [79]	validation_0-rmse:5222.58
# [40]	validation_0-rmse:3638.79
# [41]	validation_0-rmse:3562.8
# [42]	validation_0-rmse:3490.41
# [43]	validation_0-rmse:3422.74
# [44]	validation_0-rmse:3355.36
# [45]	validation_0-rmse:3289.68
# [46]	validation_0-rmse:3226.86
# [47]	validation_0-rmse:3167.59
# [48]	validation_0-rmse:3111.26
# [49]	validation_0-rmse:3051.7
# [50]	validation_0-rmse:2996.75
# [51]	validation_0-rmse:2943.29
# [52]	validation_0-rmse:2893.36
# [53]	validation_0-rmse:2847.07
# [54]	validation_0-rmse:2801.6
# [55]	validation_0-rmse:2758.31
# [56]	validation_0-rmse:2714.31
# [57]	validation_0-rmse:2675.52
# [58]	validation_0-rmse:2633.72
# [59]	validation_0-rmse:2596.36
# [60]	validation_0-rmse:2560.24
# [61]	validation_0-rmse:2526.35
# [62]	validation_0-rmse:2494.49
# [63]	validation_0-rmse:2460.03
# [64]	validation_0-rmse:2427.93
# [65]	validation_0-rmse:2399.35
# [66]	validation_0-rmse:2369.14
# [67]	validation_0-rmse:2341.66
# [68]	validation_0-rmse:2314.84
# [69]	validation_0-rmse:2289.57
# [70]	validation_0-rmse:2265.66
# [71]	validation_0-rmse:2242.99
# [72]	validation_0-rmse:2221.42
# [73]	validation_0-rmse:2203.24
# [74]	validation_0-rmse:2182.8
# [75]	validation_0-rmse:2164.61
# [76]	validation_0-rmse:2147.4
# [77]	validation_0-rmse:2130.57
# [78]	validation_0-rmse:2113.02
# [79]	validation_0-rmse:2096.93
# [80]	validation_0-rmse:2082.61
# [81]	validation_0-rmse:2068.75
# [82]	validation_0-rmse:2055.79
# [83]	validation_0-rmse:2042.15
# [84]	validation_0-rmse:2032.15
# [85]	validation_0-rmse:2020.59
# [86]	validation_0-rmse:2008.73
# [87]	validation_0-rmse:1998.89
# [88]	validation_0-rmse:1988.22
# [89]	validation_0-rmse:1979.07
# [90]	validation_0-rmse:1971.37
# [91]	validation_0-rmse:1961.62
# [92]	validation_0-rmse:1954.3
# [93]	validation_0-rmse:1942.89
# [94]	validation_0-rmse:1934.22
# [95]	validation_0-rmse:1924.8
# [96]	validation_0-rmse:1919.05
# [97]	validation_0-rmse:1910.41
# [98]	validation_0-rmse:1904.54
# [99]	validation_0-rmse:1898.52
# [11:17:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:9997.75
# Will train until validation_0-rmse hasn't improved in 5 rounds.
# [1]	validation_0-rmse:9719.16
# [2]	validation_0-rmse:9449.25
# [3]	validation_0-rmse:9187.42
# [4]	validation_0-rmse:8933.83
# [5]	validation_0-rmse:8688
# [6]	validation_0-rmse:8449.86
# [7]	validation_0-rmse:8219.16
# [8]	validation_0-rmse:7995.76
# [9]	validation_0-rmse:7779.48
# [10]	validation_0-rmse:7570.33
# [11]	validation_0-rmse:7368.01
# [12]	validation_0-rmse:7171.16
# [13]	validation_0-rmse:6981.28
# [14]	validation_0-rmse:6797.57
# [15]	validation_0-rmse:6620.22
# [16]	validation_0-rmse:6447.7
# [17]	validation_0-rmse:6280.29
# [18]	validation_0-rmse:6118.42
# [19]	validation_0-rmse:5961.14
# [60]	validation_0-rmse:2573.84
# [61]	validation_0-rmse:2536.88
# [62]	validation_0-rmse:2502.91
# [63]	validation_0-rmse:2468.76
# [64]	validation_0-rmse:2432.8
# [65]	validation_0-rmse:2398.53
# [66]	validation_0-rmse:2368.51
# [67]	validation_0-rmse:2341.46
# [68]	validation_0-rmse:2310.69
# [69]	validation_0-rmse:2286.83
# [70]	validation_0-rmse:2260.22
# [71]	validation_0-rmse:2234.84
# [72]	validation_0-rmse:2213.09
# [73]	validation_0-rmse:2189.9
# [74]	validation_0-rmse:2167.93
# [75]	validation_0-rmse:2146.13
# [76]	validation_0-rmse:2126.32
# [77]	validation_0-rmse:2108.55
# [78]	validation_0-rmse:2088.97
# [79]	validation_0-rmse:2070.88
# [80]	validation_0-rmse:2057.9
# [81]	validation_0-rmse:2042.58
# [82]	validation_0-rmse:2030.13
# [83]	validation_0-rmse:2018.56
# [84]	validation_0-rmse:2003.6
# [85]	validation_0-rmse:1990.79
# [86]	validation_0-rmse:1979.07
# [87]	validation_0-rmse:1968.82
# [88]	validation_0-rmse:1957.8
# [89]	validation_0-rmse:1949.36
# [90]	validation_0-rmse:1939.93
# [91]	validation_0-rmse:1929.97
# [92]	validation_0-rmse:1920.21
# [93]	validation_0-rmse:1911.13
# [94]	validation_0-rmse:1904.76
# [95]	validation_0-rmse:1898.51
# [96]	validation_0-rmse:1890.94
# [97]	validation_0-rmse:1882.76
# [98]	validation_0-rmse:1875.77
# [99]	validation_0-rmse:1870.6
# [11:17:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:10001.9
# Will train until validation_0-rmse hasn't improved in 5 rounds.
# [1]	validation_0-rmse:9728.49
# [2]	validation_0-rmse:9463.46
# [3]	validation_0-rmse:9207.26
# [4]	validation_0-rmse:8959.29
# [5]	validation_0-rmse:8718.97
# [6]	validation_0-rmse:8486.79
# [7]	validation_0-rmse:8261.74
# [8]	validation_0-rmse:8043.85
# [9]	validation_0-rmse:7833.23
# [10]	validation_0-rmse:7629.2
# [11]	validation_0-rmse:7432.18
# [12]	validation_0-rmse:7241.57
# [13]	validation_0-rmse:7056.71
# [14]	validation_0-rmse:6878.3
# [15]	validation_0-rmse:6706.62
# [16]	validation_0-rmse:6541.35
# [17]	validation_0-rmse:6379.68
# [18]	validation_0-rmse:6224.83
# [19]	validation_0-rmse:6073.64
# [20]	validation_0-rmse:5927.79
# [21]	validation_0-rmse:5786.67
# [22]	validation_0-rmse:5650.09
# [23]	validation_0-rmse:5518.84
# [24]	validation_0-rmse:5391.28
# [25]	validation_0-rmse:5268.42
# [26]	validation_0-rmse:5149.55
# [27]	validation_0-rmse:5034.86
# [28]	validation_0-rmse:4923.95
# [29]	validation_0-rmse:4818.37
# [30]	validation_0-rmse:4714.8
# [31]	validation_0-rmse:4616.93
# [32]	validation_0-rmse:4522.1
# [33]	validation_0-rmse:4429.25
# [34]	validation_0-rmse:4339.52
# [35]	validation_0-rmse:4254.67
# [36]	validation_0-rmse:4171.01
# [37]	validation_0-rmse:4091.06
# [38]	validation_0-rmse:4014.91
# [39]	validation_0-rmse:3942.18
41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:9998.15
# Will train until validation_0-rmse hasn't improved in 5 rounds.
# [1]	validation_0-rmse:9720.18
# [2]	validation_0-rmse:9448.43
# [3]	validation_0-rmse:9184.97
# [4]	validation_0-rmse:8929.59
# [5]	validation_0-rmse:8684.02
# [6]	validation_0-rmse:8445.15
# [7]	validation_0-rmse:8212.6
# [8]	validation_0-rmse:7988.12
# [9]	validation_0-rmse:7770.72
# [10]	validation_0-rmse:7559.76
# [11]	validation_0-rmse:7355.8
# [12]	validation_0-rmse:7157.08
# [13]	validation_0-rmse:6966.76
# [14]	validation_0-rmse:6780.66
# [15]	validation_0-rmse:6602.85
# [16]	validation_0-rmse:6428.88
# [17]	validation_0-rmse:6262.69
# [18]	validation_0-rmse:6099.8
# [19]	validation_0-rmse:5943.84
# [20]	validation_0-rmse:5790.96
# [21]	validation_0-rmse:5645.11
# [22]	validation_0-rmse:5504
# [23]	validation_0-rmse:5367.25
# [24]	validation_0-rmse:5237.57
# [25]	validation_0-rmse:5109.97
# [26]	validation_0-rmse:4986.88
# [27]	validation_0-rmse:4868.55
# [28]	validation_0-rmse:4752.47
# [29]	validation_0-rmse:4642.48
# [30]	validation_0-rmse:4534.75
# [31]	validation_0-rmse:4429.54
# [32]	validation_0-rmse:4328.31
# [33]	validation_0-rmse:4231.13
# [34]	validation_0-rmse:4137.39
# [35]	validation_0-rmse:4048.72
# [36]	validation_0-rmse:3961.04
# [37]	validation_0-rmse:3876.61
# [38]	validation_0-rmse:3796.17
# [39]	validation_0-rmse:3716.4
# [40]	validation_0-rmse:3640.18
# [41]	validation_0-rmse:3569.04
# [42]	validation_0-rmse:3499.1
# [43]	validation_0-rmse:3431.22
# [44]	validation_0-rmse:3366.8
# [45]	validation_0-rmse:3302.31
# [46]	validation_0-rmse:3241.71
# [47]	validation_0-rmse:3183.74
# [48]	validation_0-rmse:3127.38
# [49]	validation_0-rmse:3071.91
# [50]	validation_0-rmse:3019.87
# [51]	validation_0-rmse:2969.42
# [52]	validation_0-rmse:2922.53
# [53]	validation_0-rmse:2876.78
# [54]	validation_0-rmse:2833.68
# [55]	validation_0-rmse:2791.21
# [56]	validation_0-rmse:2751.38
# [57]	validation_0-rmse:2711.8
# [58]	validation_0-rmse:2675.89
# [59]	validation_0-rmse:2639.98
# [60]	validation_0-rmse:2604.2
# [61]	validation_0-rmse:2573.36
# [62]	validation_0-rmse:2540.74
# [63]	validation_0-rmse:2509.27
# [64]	validation_0-rmse:2479.65
# [65]	validation_0-rmse:2450.92
# [66]	validation_0-rmse:2423.33
# [67]	validation_0-rmse:2397.96
# [68]	validation_0-rmse:2372.51
# [69]	validation_0-rmse:2348.22
# [70]	validation_0-rmse:2326.15
# [71]	validation_0-rmse:2304.62
# [72]	validation_0-rmse:2284.48
# [73]	validation_0-rmse:2265.26
# [74]	validation_0-rmse:2246.27
# [75]	validation_0-rmse:2227.47
# [76]	validation_0-rmse:2210.01
# [77]	validation_0-rmse:2193.71
# [78]	validation_0-rmse:2175.96
# [79]	validation_0-rmse:2161.69
# [80]	validation_0-rmse:2147.15
# [81]	validation_0-rmse:2129.5
# [82]	validation_0-rmse:2115.1
# [83]	validation_0-rmse:2100.45
# [84]	validation_0-rmse:2088.06
# [85]	validation_0-rmse:2072.98
# [86]	validation_0-rmse:2061.06
# [87]	validation_0-rmse:2050.39
# [88]	validation_0-rmse:2039.89
# [89]	validation_0-rmse:2026.66
# [90]	validation_0-rmse:2014.41
# [91]	validation_0-rmse:2004.83
# [92]	validation_0-rmse:1994.53
# [93]	validation_0-rmse:1986.4
# [94]	validation_0-rmse:1977.7
# [95]	validation_0-rmse:1967.56
# [96]	validation_0-rmse:1959.74
# [97]	validation_0-rmse:1950.35
# [98]	validation_0-rmse:1942.26
# [99]	validation_0-rmse:1934.93
# [100]	validation_0-rmse:1928.86
# [101]	validation_0-rmse:1923.19
# [102]	validation_0-rmse:1917.42
# [103]	validation_0-rmse:1911.7
# [104]	validation_0-rmse:1905.16
# [105]	validation_0-rmse:1901.52
# [106]	validation_0-rmse:1895.89
# [107]	validation_0-rmse:1892.79
# [108]	validation_0-rmse:1890.55
# [109]	validation_0-rmse:1887.32
# [110]	validation_0-rmse:1885.29
# [111]	validation_0-rmse:1882.46
# [112]	validation_0-rmse:1880.05
# [113]	validation_0-rmse:1877.92
# [114]	validation_0-rmse:1876.44
# [115]	validation_0-rmse:1874.2
# [116]	validation_0-rmse:1872.36
# [117]	validation_0-rmse:1869.49
# [118]	validation_0-rmse:1867.22
# [119]	validation_0-rmse:1864.57
# [120]	validation_0-rmse:1862.2
# [121]	validation_0-rmse:1859.89
# [122]	validation_0-rmse:1857.52
# [123]	validation_0-rmse:1856.23
# [124]	validation_0-rmse:1854.87
# [125]	validation_0-rmse:1853.86
# [126]	validation_0-rmse:1852.75
# [127]	validation_0-rmse:1851.64
# [128]	validation_0-rmse:1850.26
# [129]	validation_0-rmse:1849.56
# [130]	validation_0-rmse:1847.86
# [131]	validation_0-rmse:1846.77
# [132]	validation_0-rmse:1845.86
# [133]	validation_0-rmse:1846.6
# [134]	validation_0-rmse:1844.86
# [135]	validation_0-rmse:1844.21
# [136]	validation_0-rmse:1842.85
# [137]	validation_0-rmse:1842.26
# [138]	validation_0-rmse:1841.99
# [139]	validation_0-rmse:1841.22
# [140]	validation_0-rmse:1840.95
# [141]	validation_0-rmse:1840.68
# [142]	validation_0-rmse:1840.14
# [143]	validation_0-rmse:1840.22
# [144]	validation_0-rmse:1839.9
# [145]	validation_0-rmse:1840.03
# [146]	validation_0-rmse:1839.99
# [147]	validation_0-rmse:1840.02
# [148]	validation_0-rmse:1839.69
# [149]	validation_0-rmse:1840.14
# [11:17:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:10002.3
# Will train until validation_0-rmse hasn't improved in 5 rounds.
# [1]	validation_0-rmse:9728.63
# [2]	validation_0-rmse:9463.51
# [3]	validation_0-rmse:9207.6
# [4]	validation_0-rmse:8959.69
# [5]	validation_0-rmse:8719.48
# [6]	validation_0-rmse:8487.16
# [7]	validation_0-rmse:8261.89
# [8]	validation_0-rmse:8043.44
# [9]	validation_0-rmse:7832.87
# [10]	validation_0-rmse:7628.8
# [92]	validation_0-rmse:2248.18
# [93]	validation_0-rmse:2239.09
# [94]	validation_0-rmse:2229.23
# [95]	validation_0-rmse:2221.49
# [96]	validation_0-rmse:2213.67
# [97]	validation_0-rmse:2205.83
# [98]	validation_0-rmse:2199.13
# [99]	validation_0-rmse:2192.24
# [100]	validation_0-rmse:2184.79
# [101]	validation_0-rmse:2177.78
# [102]	validation_0-rmse:2170.53
# [103]	validation_0-rmse:2163.46
# [104]	validation_0-rmse:2157.77
# [105]	validation_0-rmse:2150.39
# [106]	validation_0-rmse:2144.44
# [107]	validation_0-rmse:2138.36
# [108]	validation_0-rmse:2133.76
# [109]	validation_0-rmse:2128.44
# [110]	validation_0-rmse:2123.63
# [111]	validation_0-rmse:2120.06
# [112]	validation_0-rmse:2115.96
# [113]	validation_0-rmse:2111.49
# [114]	validation_0-rmse:2106.97
# [115]	validation_0-rmse:2102.91
# [116]	validation_0-rmse:2098.64
# [117]	validation_0-rmse:2094.93
# [118]	validation_0-rmse:2092.04
# [119]	validation_0-rmse:2088.23
# [120]	validation_0-rmse:2084.84
# [121]	validation_0-rmse:2080.92
# [122]	validation_0-rmse:2077.07
# [123]	validation_0-rmse:2074.21
# [124]	validation_0-rmse:2070.97
# [125]	validation_0-rmse:2068.29
# [126]	validation_0-rmse:2065.69
# [127]	validation_0-rmse:2061.98
# [128]	validation_0-rmse:2058.3
# [129]	validation_0-rmse:2055.15
# [130]	validation_0-rmse:2053.59
# [131]	validation_0-rmse:2051.21
# [132]	validation_0-rmse:2048.23
# [133]	validation_0-rmse:2044.87
# [134]	validation_0-rmse:2041.49
# [135]	validation_0-rmse:2038.28
# [136]	validation_0-rmse:2036.31
# [137]	validation_0-rmse:2033.04
# [138]	validation_0-rmse:2030.01
# [139]	validation_0-rmse:2026.91
# [140]	validation_0-rmse:2024.6
# [141]	validation_0-rmse:2022.19
# [142]	validation_0-rmse:2018.99
# [143]	validation_0-rmse:2016.74
# [144]	validation_0-rmse:2014.84
# [145]	validation_0-rmse:2012.98
# [146]	validation_0-rmse:2010.25
# [147]	validation_0-rmse:2008.56
# [148]	validation_0-rmse:2007.03
# [149]	validation_0-rmse:2004.84
# [11:17:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:9997.14
# Will train until validation_0-rmse hasn't improved in 5 rounds.
# [1]	validation_0-rmse:9718.29
# [2]	validation_0-rmse:9448.33
# [3]	validation_0-rmse:9186.45
# [4]	validation_0-rmse:8933.45
# [5]	validation_0-rmse:8688.11
# [6]	validation_0-rmse:8450.29
# [7]	validation_0-rmse:8217.52
# [8]	validation_0-rmse:7991.54
# [9]	validation_0-rmse:7772.76
# [10]	validation_0-rmse:7560.67
# [11]	validation_0-rmse:7355.35
# [12]	validation_0-rmse:7156
# [13]	validation_0-rmse:6963.05
# [14]	validation_0-rmse:6777.19
# [15]	validation_0-rmse:6597.25
# [16]	validation_0-rmse:6422.32
# [17]	validation_0-rmse:6253.78
# [18]	validation_0-rmse:6090.6
# [19]	validation_0-rmse:5932.7
# [20]	validation_0-rmse:5779.68
# [21]	validation_0-rmse:5631.4
# [22]	validation_0-rmse:5488.04
# [23]	validation_0-rmse:5349.18
# [24]	validation_0-rmse:5217.35
# [25]	validation_0-rmse:5087.76
# [26]	validation_0-rmse:4963.85
# [27]	validation_0-rmse:4843.02
# [28]	validation_0-rmse:4727.27
# [29]	validation_0-rmse:4614.79
# [30]	validation_0-rmse:4507.68
# [31]	validation_0-rmse:4403.23
# [32]	validation_0-rmse:4302.66
# [33]	validation_0-rmse:4205.89
# [34]	validation_0-rmse:4111.53
# [35]	validation_0-rmse:4021.18
# [36]	validation_0-rmse:3933.11
# [37]	validation_0-rmse:3847.28
# [38]	validation_0-rmse:3765.9
# [39]	validation_0-rmse:3686.38
# [40]	validation_0-rmse:3610.92
# [41]	validation_0-rmse:3536.77
# [42]	validation_0-rmse:3465.14
# [43]	validation_0-rmse:3397.13
# [44]	validation_0-rmse:3330.27
# [45]	validation_0-rmse:3267.09
# [46]	validation_0-rmse:3206.07
# [47]	validation_0-rmse:3147.17
# [48]	validation_0-rmse:3089.5
# [49]	validation_0-rmse:3034.82
# [50]	validation_0-rmse:2984.2
# [51]	validation_0-rmse:2934.5
# [52]	validation_0-rmse:2886.48
# [53]	validation_0-rmse:2840.55
# [54]	validation_0-rmse:2798
# [55]	validation_0-rmse:2756.69
# [56]	validation_0-rmse:2717.15
# [57]	validation_0-rmse:2677.69
# [58]	validation_0-rmse:2640.25
# [59]	validation_0-rmse:2604.89
# [60]	validation_0-rmse:2570.28
# [61]	validation_0-rmse:2536.29
# [62]	validation_0-rmse:2504.78
# [63]	validation_0-rmse:2473.34
# [64]	validation_0-rmse:2444.08
# [65]	validation_0-rmse:2415.23
# [66]	validation_0-rmse:2388.32
# [67]	validation_0-rmse:2361.93
# [68]	validation_0-rmse:2336.64
# [69]	validation_0-rmse:2313.14
# [70]	validation_0-rmse:2287.71
# [71]	validation_0-rmse:2264.11
# [72]	validation_0-rmse:2241.08
# [73]	validation_0-rmse:2219.21
# [74]	validation_0-rmse:2198.65
# [75]	validation_0-rmse:2180.86
# [76]	validation_0-rmse:2161.6
# [77]	validation_0-rmse:2143.55
# [78]	validation_0-rmse:2125.13
# [79]	validation_0-rmse:2107.06
# [80]	validation_0-rmse:2090.41
# [81]	validation_0-rmse:2073.86
# [82]	validation_0-rmse:2058.41
# [83]	validation_0-rmse:2042.77
# [84]	validation_0-rmse:2028.78
# [85]	validation_0-rmse:2014.9
# [86]	validation_0-rmse:2001.7
# [87]	validation_0-rmse:1988.7
# [88]	validation_0-rmse:1976.78
# [89]	validation_0-rmse:1963.95
# [90]	validation_0-rmse:1953.1
# [91]	validation_0-rmse:1942.6
# [92]	validation_0-rmse:1932.16
# [93]	validation_0-rmse:1923.11
# [94]	validation_0-rmse:1914.01
# [95]	validation_0-rmse:1903.39
# [96]	validation_0-rmse:1894.47
# [97]	validation_0-rmse:1885.45
# [98]	validation_0-rmse:1877.09
# [99]	validation_0-rmse:1868.66
# [100]	validation_0-rmse:1861.94
# [101]	validation_0-rmse:1854.45
# [102]	validation_0-rmse:1847.95
# [103]	validation_0-rmse:1841.24
# [104]	validation_0-rmse:1835.27
# [105]	validation_0-rmse:1830.07
# [106]	validation_0-rmse:1825.69
# [107]	validation_0-rmse:1821.19
# [108]	validation_0-rmse:1817.06
# [109]	validation_0-rmse:1810.89
# [110]	validation_0-rmse:1807.13
# [111]	validation_0-rmse:1803.25
# [112]	validation_0-rmse:1799.84
# [113]	validation_0-rmse:1796.51
# [114]	validation_0-rmse:1791.77
# [115]	validation_0-rmse:1788.35
# [116]	validation_0-rmse:1785.58
# [117]	validation_0-rmse:1781.81
# [118]	validation_0-rmse:1779.16
# [119]	validation_0-rmse:1777.26
# [120]	validation_0-rmse:1774.84
# [121]	validation_0-rmse:1771.21
# [122]	validation_0-rmse:1769.58
# [123]	validation_0-rmse:1768.19
# [124]	validation_0-rmse:1766.34
# [125]	validation_0-rmse:1764.33
# [126]	validation_0-rmse:1762.29
# [127]	validation_0-rmse:1760.92
# [128]	validation_0-rmse:1759.59
# [129]	validation_0-rmse:1757.95
# [130]	validation_0-rmse:1757.34
# [131]	validation_0-rmse:1755.95
# [132]	validation_0-rmse:1755.1
# [133]	validation_0-rmse:1753.74
# [134]	validation_0-rmse:1753.58
# [135]	validation_0-rmse:1753.37
# [136]	validation_0-rmse:1752.9
# [137]	validation_0-rmse:1752.92
# [138]	validation_0-rmse:1750.82
# [139]	validation_0-rmse:1751.39
# [140]	validation_0-rmse:1750.28
# [141]	validation_0-rmse:1750.3
# [142]	validation_0-rmse:1749.07
# [143]	validation_0-rmse:1749.35
# [144]	validation_0-rmse:1748.5
# [145]	validation_0-rmse:1747.19
# [146]	validation_0-rmse:1746.41
# [147]	validation_0-rmse:1747.47
# [148]	validation_0-rmse:1746.11
# [149]	validation_0-rmse:1746.78
# best_estimator_  XGBRegressor(learning_rate=0.03, max_depth=10, n_estimators=150,
#              random_state=42)

# %%
xgbr_model = search.best_estimator_
xgbr_model.fit(x_train, y_train)
train_score = xgbr_model.score(x_train, y_train)
print('training score = ', train_score)
test_score = xgbr_model.score(x_test, y_test)
print('testing score = ', test_score)
# Out:
# [11:17:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# training score =  0.9587408596730007
# testing score =  0.8372818701296354

# %%
y_pred = xgbr_model.predict(x_test)
MAE = mean_absolute_error(y_test, y_pred)
print('MAE = ', MAE)
MSE = np.sqrt(mean_squared_error(y_test, y_pred))
print('MSE = ', MSE)
R2 = r2_score(y_test, y_pred)
print('R2 = ', R2)
adj_r2 = 1-(1-R2)*(test_len-1)/(test_len-cols_len-1)
print('adjusted R2 = ', adj_r2)
# Out:
# MAE =  781.0462059463854
# MSE =  1775.5994015545625
# R2 =  0.8372818701296354
# adjusted R2 =  0.8362769600639277

# %%
results = results.append({'model_name':'XGB', 'train_score':train_score, 'test_score':test_score, 'MSE':MSE, 'MAE':MAE, 'R2':R2, 'Adjusted_R2':adj_r2}, ignore_index=True)

# %% [markdown]
# ## Gradient Boosting

# %%
gbr_model = GradientBoostingRegressor()
gbr_params = {
    "n_estimators": [100, 150, 200],
    "max_depth": [7, 8, 9, 10, 11],
    "random_state": [None, 42],
    "learning_rate": [0.03, 0.01],
    "alpha": [0, 0.01, 0.025],
}
search = RandomizedSearchCV(estimator=gbr_model, param_distributions=gbr_params, cv=kf)
search.fit(x_train, y_train)
print("best_estimator_ ",search.best_estimator_)
# Out:
# best_estimator_  GradientBoostingRegressor(alpha=0.01, learning_rate=0.03, max_depth=10,
#                           n_estimators=200)

# %%
gbr_model = search.best_estimator_
gbr_model.fit(x_train, y_train)
train_score = gbr_model.score(x_train, y_train)
print('training score = ', train_score)
test_score = gbr_model.score(x_test, y_test)
print('testing score = ', test_score)
# Out:
# training score =  0.9861280822566909
# testing score =  0.846377211326075

# %%
y_pred = gbr_model.predict(x_test)
MAE = mean_absolute_error(y_test, y_pred)
print('MAE = ', MAE)
MSE = np.sqrt(mean_squared_error(y_test, y_pred))
print('MSE = ', MSE)
R2 = r2_score(y_test, y_pred)
print('R2 = ', R2)
adj_r2 = 1-(1-R2)*(test_len-1)/(test_len-cols_len-1)
print('adjusted R2 = ', adj_r2)
# Out:
# MAE =  676.8389639506613
# MSE =  1725.2611391202202
# R2 =  0.846377211326075
# adjusted R2 =  0.8454284720135995

# %%
results = results.append({'model_name':'GBR', 'train_score':train_score, 'test_score':test_score, 'MSE':MSE, 'MAE':MAE, 'R2':R2, 'Adjusted_R2':adj_r2}, ignore_index=True)

# %% [markdown]
# ## MLP Regressor

# %%
mlp_model = MLPRegressor(hidden_layer_sizes=2000, max_iter=2000, random_state=42)
mlp_model.fit(x_train, y_train)
train_score = mlp_model.score(x_train, y_train)
print('training score = ', train_score)
test_score = mlp_model.score(x_test, y_test)
print('testing score = ', test_score)
# Out:
# training score =  0.7999325188594371
# testing score =  0.7733110363214069

# %%
y_pred = mlp_model.predict(x_test)
MAE = mean_absolute_error(y_test, y_pred)
print('MAE = ', MAE)
MSE = np.sqrt(mean_squared_error(y_test, y_pred))
print('MSE = ', MSE)
R2 = r2_score(y_test, y_pred)
print('R2 = ', R2)
adj_r2 = 1-(1-R2)*(test_len-1)/(test_len-cols_len-1)
print('adjusted R2 = ', adj_r2)
# Out:
# MAE =  1374.9505582967931
# MSE =  2095.763181614661
# R2 =  0.7733110363214069
# adjusted R2 =  0.771911056973273

# %%
results = results.append({'model_name':'MLPR', 'train_score':train_score, 'test_score':test_score, 'MSE':MSE, 'MAE':MAE, 'R2':R2, 'Adjusted_R2':adj_r2}, ignore_index=True)

# %%
results.head()
# Out:
#       model_name  train_score  test_score          MSE          MAE        R2  \
# 0   Decsion_tree     0.942527    0.785872  2036.870675   854.004951  0.785872
# 1  Random_forest     0.924615    0.838294  1770.069291   909.696311  0.838294
# 2            XGB     0.958741    0.837282  1775.599402   781.046206  0.837282
# 3            GBR     0.986128    0.846377  1725.261139   676.838964  0.846377
# 4           MLPR     0.799933    0.773311  2095.763182  1374.950558  0.773311
#
#    Adjusted_R2
# 0     0.784550
# 1     0.837295
# 2     0.836277
# 3     0.845428
# 4     0.771911

# %%
results.to_csv('results.csv')
